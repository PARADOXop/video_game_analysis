# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
sales_df = pd.read_csv('./dataset/vgsales.csv')
reviews_df = pd.read_csv('./dataset/games.csv')

# %% [markdown]
# # cleaning and preprocess

# %% [markdown]
# ##### 1. rename columns into proper names and remove unwanted columns

# %%
gsales_names = {'Rank': 'rank', 'Name' : 'title', 'Platform' : 'platform', 'Year': 'year', 'Genre': 'genre', 'Publisher': 'publisher', 'NA_Sales' : 'na_Sales',
                'EU_Sales': 'eu_sales', 'JP_Sales': 'jp_sales', 'Other_Sales': 'other_sales', 'Global_Sales': 'global_sales'} 

reviews_names = {'Title': 'title', 'Release Date': 'release_date', 'Team': 'team', 'Rating': 'rating', 'Times Listed': 'times_listed', 'Number of Reviews': 'review_cnt', 'Genres': 
             'genres', 'Summary': 'summary', 'Reviews': 'reviews', 'Plays': 'plays', 'Backlogs': 'backlogs', 'Wishlist': 'wishlist'}
sales_df.rename(columns = gsales_names, inplace = True)
reviews_df.rename(columns = reviews_names, inplace = True)
reviews_df.drop(columns = ['Unnamed: 0', 'summary', 'reviews'], inplace = True)

# %%
sales_df.isna().sum()
# Out:
# rank              0
# title             0
# platform          0
# year            271
# genre             0
# publisher        58
# na_Sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %% [markdown]
# ##### 2. check, understand and handle nulls

# %%
sales_df['year'] = sales_df['year'].fillna(0)
sales_df.fillna({'publisher': 'Unknown'}, inplace = True)
reviews_df.isna().sum()
# Out:
# title            0
# release_date     0
# team             1
# rating          13
# times_listed     0
# review_cnt       0
# genres           0
# plays            0
# Playing          0
# backlogs         0
# wishlist         0
# dtype: int64

# %%
reviews_df = reviews_df[~reviews_df['rating'].isna()]
reviews_df.isna().sum()
# Out:
# title           0
# release_date    0
# team            1
# rating          0
# times_listed    0
# review_cnt      0
# genres          0
# plays           0
# Playing         0
# backlogs        0
# wishlist        0
# dtype: int64

# %%
import ast
reviews_df['genres'] = reviews_df['genres'].apply(ast.literal_eval)

def normalize_team(x):
    if pd.isna(x):
        return ['Unknown']
    if isinstance(x, list):
        return x
    if isinstance(x, str):
        return ast.literal_eval(x)
    return ['Unknown']

reviews_df['team'] = reviews_df['team'].apply(normalize_team)
reviews_df['genres'] = reviews_df['genres'].apply( lambda x: 'unknown' if len(x) == 0 else x)

# %% [markdown]
# ##### 3. check for duplicates and drop

# %%
sales_df.drop_duplicates(inplace = True)

# %%
reviews_df['title'].value_counts().reset_index(name = 'cnt').sort_values(by = 'cnt', ascending = False).head(5)
# Out:
#                     title  cnt
# 0                    Doom    7
# 1  Shadow of the Colossus    5
# 2         Resident Evil 2    5
# 3              Dead Space    5
# 4       Final Fantasy VII    4

# %%
reviews_df[reviews_df['title'] == 'Doom']
# Out:
#      title  release_date                               team  rating  \
# 45    Doom  May 12, 2016  [id Software, Bethesda Softworks]     4.0
# 132   Doom  Dec 10, 1993          [Activision, id Software]     4.0
# 371   Doom  May 12, 2016  [id Software, Bethesda Softworks]     4.0
# 421   Doom  Dec 10, 1993          [Activision, id Software]     4.0
# 821   Doom  May 12, 2016  [id Software, Bethesda Softworks]     4.0
# 887   Doom  Dec 10, 1993          [Activision, id Software]     4.0
# 1332  Doom  Nov 10, 2017  [Bethesda Softworks, id Software]     3.9
#
#      times_listed review_cnt     genres plays Playing backlogs wishlist
# 45           1.8K       1.8K  [Shooter]   18K     541       4K     1.4K
# 132          1.4K       1.4K  [Shooter]   11K     203     1.5K      514
# 371          1.8K       1.8K  [Shooter]   18K     541       4K     1.4K
# 421          1.4K       1.4K  [Shooter]   11K     203     1.5K      514
# 821          1.8K       1.8K  [Shooter]   18K     541       4K     1.4K
# 887          1.4K       1.4K  [Shooter]   11K     203     1.5K      514
# 1332           80         80  [Shooter]  2.3K      37      393      150

# %%
reviews_df[reviews_df['title'] == 'Resident Evil 2']
# Out:
#                 title  release_date                                     team  \
# 44    Resident Evil 2  Jan 25, 2019  [Capcom, Capcom Development Division 1]
# 370   Resident Evil 2  Jan 25, 2019  [Capcom, Capcom Development Division 1]
# 513   Resident Evil 2  Jan 21, 1998                       [Capcom, Factor 5]
# 820   Resident Evil 2  Jan 25, 2019  [Capcom, Capcom Development Division 1]
# 1026  Resident Evil 2  Jan 21, 1998                       [Capcom, Factor 5]
#
#       rating times_listed review_cnt                genres plays Playing  \
# 44       4.3         2.5K       2.5K  [Adventure, Shooter]   15K     585
# 370      4.3         2.5K       2.5K  [Adventure, Shooter]   15K     585
# 513      4.2         1.1K       1.1K  [Adventure, Shooter]  5.5K      54
# 820      4.3         2.5K       2.5K  [Adventure, Shooter]   15K     585
# 1026     4.2         1.1K       1.1K  [Adventure, Shooter]  5.5K      54
#
#      backlogs wishlist
# 44       3.6K     1.9K
# 370      3.6K     1.9K
# 513      1.1K      597
# 820      3.6K     1.9K
# 1026     1.1K      597

# %%
reviews_df.drop_duplicates(['title', 'release_date'], inplace = True)
reviews_df
# Out:
#                                         title  release_date  \
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                  team  rating times_listed  \
# 0          [Bandai Namco Entertainment, FromSoftware]     4.5         3.9K
# 1                                  [Supergiant Games]     4.3         2.9K
# 2     [Nintendo, Nintendo EPD Production Group No. 3]     4.4         4.3K
# 3                                      [tobyfox, 8-4]     4.2         3.5K
# 4                                       [Team Cherry]     4.4           3K
# ...                                               ...     ...          ...
# 1507                                 [Telltale Games]     3.2           94
# 1508                             [Sumo Digital, Sega]     2.9          264
# 1509                                         [Capcom]     3.7          210
# 1510                                 [Larian Studios]     4.1          165
# 1511                            [WB Games, TT Fusion]     2.8          184
#
#      review_cnt                                             genres plays  \
# 0          3.9K                                   [Adventure, RPG]   17K
# 1          2.9K                   [Adventure, Brawler, Indie, RPG]   21K
# 2          4.3K                                   [Adventure, RPG]   30K
# 3          3.5K       [Adventure, Indie, RPG, Turn Based Strategy]   28K
# 4            3K                       [Adventure, Indie, Platform]   21K
# ...         ...                                                ...   ...
# 1507         94                       [Adventure, Point-and-Click]   763
# 1508        264                                   [Arcade, Racing]  1.5K
# 1509        210                                     [Brawler, RPG]  1.1K
# 1510        165  [Adventure, RPG, Strategy, Tactical, Turn Base...   269
# 1511        184                                [Adventure, Puzzle]  1.7K
#
#      Playing backlogs wishlist
# 0       3.8K     4.6K     4.8K
# 1       3.2K     6.3K     3.6K
# 2       2.5K       5K     2.6K
# 3        679     4.9K     1.8K
# 4       2.4K     8.3K     2.3K
# ...      ...      ...      ...
# 1507       5      223       67
# 1508      49      413      107
# 1509      45      487      206
# 1510      79      388      602
# 1511      11      239       73
#
# [1104 rows x 11 columns]

# %% [markdown]
# ##### 4. create new table for teams, genres, platform and publisher

# %%
reviews_df['release_date'] = pd.to_datetime(reviews_df['release_date'], errors = 'coerce')
reviews_df['year'] = reviews_df['release_date'].dt.year.fillna(0).astype('int32')
games = reviews_df.drop(columns=['team', 'genres']).drop_duplicates()

game_teams = reviews_df[['title', 'year', 'team']].explode('team').drop_duplicates()

game_genres = reviews_df[['title', 'year', 'genres']].explode('genres').drop_duplicates()

game_publisher_df = sales_df[['title', 'year', 'publisher']].dropna().drop_duplicates(subset = ['title', 'publisher'])
game_platform_df = sales_df[['title', 'year', 'platform']].dropna().drop_duplicates(subset = ['title', 'platform'])
sales_df.drop_duplicates(subset=['title', 'year'], inplace = True)

# %%
gsales_genre = (
    sales_df[['title', 'genre']]
    .dropna()
    .drop_duplicates()
)

game_genres = (
    game_genres
    .rename(columns={'genres': 'genre'})
)

games_genres = pd.concat([gsales_genre, game_genres], ignore_index=True).dropna().drop_duplicates(subset = ['title', 'genre'])
game_genres
# Out:
#                          title  year                genre
# 0                   Elden Ring  2022            Adventure
# 0                   Elden Ring  2022                  RPG
# 1                        Hades  2019            Adventure
# 1                        Hades  2019              Brawler
# 1                        Hades  2019                Indie
# ...                        ...   ...                  ...
# 1510           Baldur's Gate 3  2020             Strategy
# 1510           Baldur's Gate 3  2020             Tactical
# 1510           Baldur's Gate 3  2020  Turn Based Strategy
# 1511  The LEGO Movie Videogame  2014            Adventure
# 1511  The LEGO Movie Videogame  2014               Puzzle
#
# [2660 rows x 3 columns]

# %%
sales_df.drop(columns = ['genre', 'publisher', 'platform'], inplace = True)
sales_df
# Out:
#         rank                               title    year  na_Sales  eu_sales  \
# 0          1                          Wii Sports  2006.0     41.49     29.02
# 1          2                   Super Mario Bros.  1985.0     29.08      3.58
# 2          3                      Mario Kart Wii  2008.0     15.85     12.88
# 3          4                   Wii Sports Resort  2009.0     15.75     11.01
# 4          5            Pokemon Red/Pokemon Blue  1996.0     11.27      8.89
# ...      ...                                 ...     ...       ...       ...
# 16591  16594                 Myst IV: Revelation  2004.0      0.01      0.00
# 16592  16595                            Plushees  2008.0      0.01      0.00
# 16593  16596  Woody Woodpecker in Crazy Castle 5  2002.0      0.01      0.00
# 16594  16597       Men in Black II: Alien Escape  2003.0      0.01      0.00
# 16596  16599                          Know How 2  2010.0      0.00      0.01
#
#        jp_sales  other_sales  global_sales
# 0          3.77         8.46         82.74
# 1          6.81         0.77         40.24
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 4         10.22         1.00         31.37
# ...         ...          ...           ...
# 16591      0.00         0.00          0.01
# 16592      0.00         0.00          0.01
# 16593      0.00         0.00          0.01
# 16594      0.00         0.00          0.01
# 16596      0.00         0.00          0.01
#
# [12363 rows x 8 columns]

# %% [markdown]
# ##### 5. tranform columns and assign correct datatypes

# %%
games['times_listed'] = games['times_listed'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['review_cnt'] = games['review_cnt'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['plays'] = games['plays'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['Playing'] = games['Playing'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['backlogs'] = games['backlogs'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)

games['wishlist'] = games['wishlist'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)


games
# Out:
#                                         title release_date  rating  \
# 0                                  Elden Ring   2022-02-25     4.5
# 1                                       Hades   2019-12-10     4.3
# 2     The Legend of Zelda: Breath of the Wild   2017-03-03     4.4
# 3                                   Undertale   2015-09-15     4.2
# 4                               Hollow Knight   2017-02-24     4.4
# ...                                       ...          ...     ...
# 1507             Back to the Future: The Game   2010-12-22     3.2
# 1508                        Team Sonic Racing   2019-05-21     2.9
# 1509                           Dragon's Dogma   2012-05-22     3.7
# 1510                          Baldur's Gate 3   2020-10-06     4.1
# 1511                 The LEGO Movie Videogame   2014-02-04     2.8
#
#       times_listed  review_cnt  plays  Playing  backlogs  wishlist  year
# 0             3900        3900  17000     3800      4600      4800  2022
# 1             2900        2900  21000     3200      6300      3600  2019
# 2             4300        4300  30000     2500      5000      2600  2017
# 3             3500        3500  28000      679      4900      1800  2015
# 4             3000        3000  21000     2400      8300      2300  2017
# ...            ...         ...    ...      ...       ...       ...   ...
# 1507            94          94    763        5       223        67  2010
# 1508           264         264   1500       49       413       107  2019
# 1509           210         210   1100       45       487       206  2012
# 1510           165         165    269       79       388       602  2020
# 1511           184         184   1700       11       239        73  2014
#
# [1104 rows x 10 columns]

# %%
sales_dtype = {'rank': 'int32', 'name': 'string', 'platform': 'category', 'year': 'int32', 'genre': 'category', 'publisher': 'string'}
games_dtype = {'title': 'string', 'release_date': 'datetime', 'rating': 'float', 'times_listed': 'int32', 'review_cnt': 'int32',
               'plays': 'int32', 'Playing': 'int32', 'backlogs': 'int32', 'wishlist': 'int32'}
games = games.convert_dtypes(games_dtype)
sales_df = sales_df.convert_dtypes(sales_dtype)
sales_df.info()
games = (
    games.groupby(['title', 'year'], as_index=False)
    .agg(
        rating=('rating', 'mean'),
        times_listed=('times_listed', 'sum'),
        review_cnt=('review_cnt', 'sum'),
        plays=('plays', 'sum'),
        Playing=('Playing', 'sum'),
        backlogs=('backlogs', 'sum'),
        wishlist=('wishlist', 'sum')
    )
)
game_genres.drop_duplicates(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12363 entries, 0 to 16596
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          12363 non-null  Int64
#  1   title         12363 non-null  string
#  2   year          12363 non-null  Int64
#  3   na_Sales      12363 non-null  Float64
#  4   eu_sales      12363 non-null  Float64
#  5   jp_sales      12363 non-null  Float64
#  6   other_sales   12363 non-null  Float64
#  7   global_sales  12363 non-null  Float64
# dtypes: Float64(5), Int64(2), string(1)
# memory usage: 953.8 KB

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1102 entries, 0 to 1101
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1102 non-null   string
#  1   year          1102 non-null   Int32
#  2   rating        1102 non-null   Float64
#  3   times_listed  1102 non-null   Int64
#  4   review_cnt    1102 non-null   Int64
#  5   plays         1102 non-null   Int64
#  6   Playing       1102 non-null   Int64
#  7   backlogs      1102 non-null   Int64
#  8   wishlist      1102 non-null   Int64
# dtypes: Float64(1), Int32(1), Int64(6), string(1)
# memory usage: 81.9 KB

# %% [markdown]
# ##### 6. validate numerical columns & check for outlier's

# %%
numeric_cols = games.select_dtypes(exclude=['string']).columns
for col in numeric_cols:
    print(col, games[col].min(), games[col].max())
# Out:
# year 0 2023
# rating 0.7 4.8
# times_listed 8 4300
# review_cnt 8 4300
# plays 1 33000
# Playing 0 3800
# backlogs 5 8300
# wishlist 2 4800

# %%
numeric_cols = sales_df.select_dtypes(exclude=['string']).columns
for col in numeric_cols:
    print(col, sales_df[col].min(), sales_df[col].max())
sales_df = sales_df.rename(columns={'name': 'title'})
# Out:
# rank 1 16599
# year 0 2020
# na_Sales 0.0 41.49
# eu_sales 0.0 29.02
# jp_sales 0.0 10.22
# other_sales 0.0 10.57
# global_sales 0.01 82.74

# %%
df = pd.merge(games, sales_df, on = ['title', 'year'], how = 'inner')
df
# Out:
#                                title  year  rating  times_listed  review_cnt  \
# 0                       Advance Wars  2001     3.7           266         266
# 1                          Alan Wake  2010     3.6           702         702
# 2             Alice: Madness Returns  2011     3.5           358         358
# 3                     Alpha Protocol  2010     3.3           170         170
# 4                    Animal Crossing  2001     3.9           533         533
# ..                               ...   ...     ...           ...         ...
# 411                         Yakuza 2  2006     4.0           331         331
# 412                    Yakuza Kiwami  2016     3.7          1200        1200
# 413       Ys VIII: Lacrimosa of Dana  2016     4.2           620         620
# 414  Zelda II: The Adventure of Link  1987     2.6           756         756
# 415   Zero Escape: Zero Time Dilemma  2016     3.0           350         350
#
#      plays  Playing  backlogs  wishlist   rank  na_Sales  eu_sales  jp_sales  \
# 0     1900       52       640       266   2925       0.5      0.19       0.0
# 1     6200       96      2000       741   1444      0.66      0.51      0.05
# 2     2800      113      1200       636   3352      0.22      0.25      0.04
# 3      987        9       511       182   4495      0.19      0.18       0.0
# 4     3900       51       389       317    436      1.92      0.16      0.99
# ..     ...      ...       ...       ...    ...       ...       ...       ...
# 411   1000       28       491       255   1875      0.05      0.04      0.84
# 412   9700      439      3400      1000   8659       0.0       0.0      0.16
# 413   1900      131      1100       575  11244       0.0       0.0      0.09
# 414   4500       55      1100       290    252      2.19       0.5      1.61
# 415   2900       64      1200       402  12434      0.04       0.0      0.01
#
#      other_sales  global_sales
# 0           0.01           0.7
# 1           0.13          1.35
# 2           0.09           0.6
# 3           0.07          0.43
# 4           0.09          3.15
# ..           ...           ...
# 411         0.16          1.09
# 412          0.0          0.16
# 413          0.0          0.09
# 414         0.08          4.38
# 415         0.01          0.06
#
# [416 rows x 15 columns]

# %% [markdown]
# ## Statistical Analysis

# %% [markdown]
# 1. correlation between rating and sales
# 2. Do highly wishlisted or backlogged games convert into higher sales after release?

# %%
df['avg_sales'] = df.apply(lambda x: (x['na_Sales'] + x['eu_sales'] + x['jp_sales'] + x['other_sales'] + x['global_sales']) / 5, axis = 1)

df[['rating', 'backlogs',	'wishlist', 'global_sales']].corr()
# Out:
#                 rating  backlogs  wishlist  global_sales
# rating        1.000000  0.453064  0.523202      0.039676
# backlogs      0.453064  1.000000  0.884418     -0.006129
# wishlist      0.523202  0.884418  1.000000     -0.068217
# global_sales  0.039676 -0.006129 -0.068217      1.000000

# %% [markdown]
# 1. User ratings have a moderate positive correlation with backlogs (0.45) and wishlists (0.52), meaning higher-rated games tend to appear more often in players' backlogs and wishlists.
#
# 2. Backlogs and wishlists are strongly positively correlated (0.88), indicating that games frequently wishlisted are also often left in the backlog.
#
# 3. Average sales show almost no meaningful correlation with ratings (0.04), backlogs (-0.006), or wishlists (-0.068),
# suggesting that neither player ratings nor backlog/wishlist counts strongly predict actual sales

# %% [markdown]
# 4. How has the video game market evolved by platform and region over time, and which platforms are rising or declining?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Merge datasets
sales_connect = pd.merge(sales_df, game_platform_df, on=['title', 'year'], how='inner')

# Step 1: Calculate total global sales per platform (all years combined)
total_sales_platform = sales_connect.groupby('platform', as_index=False)['global_sales'].sum()

# Step 2: Pick top 6 platforms by total global sales
top6_platforms = total_sales_platform.sort_values(by='global_sales', ascending=False).head(6)['platform'].tolist()

# Step 3: Aggregate total global sales per year and platform (same as before)
sales_agg = sales_connect.groupby(['year', 'platform'], as_index=False)['global_sales'].sum()

# Step 4: Filter to include only top 6 platforms
sales_agg_top6 = sales_agg[sales_agg['platform'].isin(top6_platforms)]

# Step 5: Plot with filtered data
plt.figure(figsize=(20, 10))
sns.barplot(data=sales_agg_top6, x='year', y='global_sales', hue='platform')
plt.title("Global Sales Over Years for Top 6 Platforms")
plt.xlabel("Year")
plt.ylabel("Global Sales")
plt.legend(title="Platform")
plt.show()

# %%
#5. Which developer studios are the most impactful, balancing productivity, ratings, engagement


# Merge main game info with team info and sales
merged = pd.merge(sales_df, game_teams, how='inner', on=['title','year'])
merged = pd.merge(merged, games, how='inner', on=['title','year'])

# Group by team and compute required metrics
team_metrics = merged.groupby('team').agg(
    num_games = ('title','count'),
    avg_rating = ('rating','mean'),
    avg_backlogs = ('backlogs','mean'),
    avg_wishlist = ('wishlist','mean'),
    avg_review_cnt = ('review_cnt','mean'),
    total_sales = ('global_sales','sum')
)

# Create a composite (impact) score (example weights, feel free to adjust)
team_metrics['impact_score'] = (
    (team_metrics['num_games'] / team_metrics['num_games'].max()) * 0.25 +
    (team_metrics['avg_rating'] / team_metrics['avg_rating'].max()) * 0.25 +
    (team_metrics['total_sales'] / team_metrics['total_sales'].max()) * 0.25 +
    ((team_metrics['avg_backlogs'] + team_metrics['avg_wishlist'] + team_metrics['avg_review_cnt']) /
      (team_metrics['avg_backlogs'] + team_metrics['avg_wishlist'] + team_metrics['avg_review_cnt']).max()) * 0.25
)

# Sort by impact score
top_teams = team_metrics.sort_values(by='impact_score', ascending=False).head(10)
plt.figure(figsize=(14,8))
sns.barplot(x=top_teams.index, y='impact_score', data=top_teams.reset_index())
plt.xticks(rotation=45)
plt.title("Top Developer Studios by Impact Score")
plt.ylabel("Impact Score")
plt.xlabel("Developer Studio")
plt.show()

# %% [markdown]
# ## Save new tables

# %%
games.to_csv('./dataset/games_ratings.csv', index = False)
game_teams.to_csv('./dataset/game_teams.csv', index = False)
game_genres.to_csv('./dataset/game_genres.csv', index = False)
sales_df.to_csv('./dataset/game_sales.csv', index = False)
game_publisher_df.to_csv('./dataset/game_publisher.csv', index = False)
game_platform_df.to_csv('./dataset/game_platform.csv', index = False)

# %%
# Left join: keep all games, attach sales if present
merged = games.merge(sales_df, on=['title','year'], how='left')

# Check how many games didn’t find a match in sales
missing_in_sales = merged['global_sales'].isna().sum()
print(f"{missing_in_sales} games missing in sales")
# Right join: keep all sales, attach games if present
merged_rev = sales_df.merge(games, on=['title','year'], how='left')
missing_in_games = merged_rev['rating'].isna().sum()
print(f"{missing_in_games} sales rows missing games")
# Out:
# 686 games missing in sales
# 11947 sales rows missing games

# %%
df = pd.merge(sales_df, games, how = 'inner', on = ['title', 'year'])
df
# Out:
#       rank                                     title  year  na_Sales  \
# 0        1                                Wii Sports  2006     41.49
# 1        2                         Super Mario Bros.  1985     29.08
# 2        3                            Mario Kart Wii  2008     15.85
# 3        6                                    Tetris  1989      23.2
# 4        7                     New Super Mario Bros.  2006     11.38
# ..     ...                                       ...   ...       ...
# 411  14230  JoJo's Bizarre Adventure: Eyes of Heaven  2015       0.0
# 412  15135                              Rule of Rose  2006      0.01
# 413  15436                    Mount & Blade: Warband  2010      0.01
# 414  15832      Phoenix Wright: Ace Attorney Trilogy  2014       0.0
# 415  16166                                   Deus Ex  2000       0.0
#
#      eu_sales  jp_sales  other_sales  global_sales  rating  times_listed  \
# 0       29.02      3.77         8.46         82.74     3.7           775
# 1        3.58      6.81         0.77         40.24     3.5          1500
# 2       12.88      3.79         3.31         35.82     3.9          1000
# 3        2.26      4.22         0.58         30.26    4.05           885
# 4        9.23       6.5          2.9         30.01     3.5           991
# ..        ...       ...          ...           ...     ...           ...
# 411       0.0      0.03          0.0          0.03     2.8           106
# 412      0.01       0.0          0.0          0.02     3.8           394
# 413      0.01       0.0          0.0          0.02     3.9           168
# 414       0.0      0.02          0.0          0.02     4.3           516
# 415      0.01       0.0          0.0          0.01     4.4           899
#
#      review_cnt  plays  Playing  backlogs  wishlist
# 0           775  18000       39       320        93
# 1          1500  18000       59       733       237
# 2          1000  19000       88       461       168
# 3           885  12100       72       251        87
# 4           991  16000      108       824       287
# ..          ...    ...      ...       ...       ...
# 411         106   1700       36       276       196
# 412         394    727       33       796       770
# 413         168   2400       39       309       110
# 414         516   4000      644      1900       779
# 415         899   3800      189      2700       958
#
# [416 rows x 15 columns]

# %% [markdown]
# Total games: 12,130
#
# Total sales rows: 12,058
#
# Common (matched) rows): 416
#
# Games missing in sales: 699
#
# Sales missing in games: 11,947
#
# Conclusion:
#
# After aggregating by (title, year), each key appears at most once in each table → 1-to-1 relationship
#
# Missing rows are normal → relationship is optional on both sides

# %% [markdown]
# # Connect data to SQL server

# %%
# SQL Server connect
import sqlalchemy
from sqlalchemy import (
    Column, Integer, Float, String, create_engine, MetaData
)
from sqlalchemy.orm import declarative_base

database_name = 'videogames'
server_name = 'DESKTOP-I3SV1NI'
driver = 'ODBC Driver 17 for SQL Server'

connect_str = f"mssql+pyodbc://{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server"


Base = declarative_base()
engine = create_engine(connect_str)

# %%
# --------------------------
# Games table

class Game(Base):
    __tablename__ = "games"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    rating = Column(Float)
    times_listed = Column(Integer)
    review_cnt = Column(Integer)
    plays = Column(Integer)
    playing = Column(Integer)
    backlogs = Column(Integer)
    wishlist = Column(Integer)



# --------------------------
# Sales table

class Sale(Base):
    __tablename__ = "sales"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    rank = Column(Integer)
    na_sales = Column(Float)
    eu_sales = Column(Float)
    jp_sales = Column(Float)
    other_sales = Column(Float)
    global_sales = Column(Float)



# --------------------------
# Game Teams

class GameTeam(Base):
    __tablename__ = "game_teams"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    team = Column(String(100), primary_key=True)


# --------------------------
# Game Genres

class GameGenre(Base):
    __tablename__ = "game_genres"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    genre = Column(String(100), primary_key=True)


# --------------------------
# Game Platform

class GamePlatform(Base):
    __tablename__ = "game_platform"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    platform = Column(String(50), primary_key=True)



# --------------------------
# Game Publisher

class GamePublisher(Base):
    __tablename__ = "game_publisher"
    
    title = Column(String(255), primary_key=True)
    year = Column(Integer, primary_key=True)
    publisher = Column(String(100), primary_key=True)


Base.metadata.create_all(engine)

# %% [markdown]
# ## Update data to SQL Tables

# %%
games.to_sql('games', con=engine, if_exists='replace', index=False)
game_platform_df.to_sql('game_platform', con=engine, if_exists='replace', index=False)
game_genres.to_sql('game_genres', con=engine, if_exists='replace', index=False)
game_teams.to_sql('game_teams', con=engine, if_exists='replace', index=False)
game_publisher_df.to_sql('game_publisher', con=engine, if_exists='replace', index=False)
sales_df.to_sql('sales', con=engine, if_exists='replace', index=False)
# Out:
# 49
