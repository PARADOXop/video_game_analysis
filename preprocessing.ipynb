# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
sales_df = pd.read_csv('./dataset/vgsales.csv')
reviews_df = pd.read_csv('./dataset/games.csv')

# %% [markdown]
# # cleaning and preprocess
# 1. rename columns into proper names and remove unwanted columns -- Done
# 2. check, understand and handle nulls --> done
# 3. check for duplicates and drop      --> done
# 4. assign correct datatypes           --> Done
# 5. create new table for teams and genres --> Done
# 6. validate numerical columns        --> Done
# 7. check for outlier's               --> Done
# 8. tranform columns as required      --> Done
# 9. Save new tables                   --> Done
# 9. Connect data to SQL server

# %%
gsales_names = {'Rank': 'rank', 'Name' : 'name', 'Platform' : 'platform', 'Year': 'year', 'Genre': 'genre', 'Publisher': 'publisher', 'NA_Sales' : 'na_Sales',
                'EU_Sales': 'eu_sales', 'JP_Sales': 'jp_sales', 'Other_Sales': 'other_sales', 'Global_Sales': 'global_sales'} 

reviews_names = {'Title': 'title', 'Release Date': 'release_date', 'Team': 'team', 'Rating': 'rating', 'Times Listed': 'times_listed', 'Number of Reviews': 'review_cnt', 'Genres': 
             'genres', 'Summary': 'summary', 'Reviews': 'reviews', 'Plays': 'plays', 'Backlogs': 'backlogs', 'Wishlist': 'wishlist'}
sales_df.rename(columns = gsales_names, inplace = True)
reviews_df.rename(columns = reviews_names, inplace = True)
reviews_df.drop(columns = ['Unnamed: 0', 'summary', 'reviews'], inplace = True)

# %%
sales_df
# Out:
#         rank                                              name platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          year         genre   publisher  na_Sales  eu_sales  jp_sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        other_sales  global_sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
sales_df.drop_duplicates(inplace = True)
sales_df.groupby(['name'])['platform'].transform('count')
# Out:
# 0        1
# 1        2
# 2        1
# 3        1
# 4        1
#         ..
# 16593    1
# 16594    2
# 16595    4
# 16596    1
# 16597    2
# Name: platform, Length: 16598, dtype: int64

# %%
reviews_df
# Out:
#                                         title  release_date  \
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    team  rating times_listed  \
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# 2     ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                    ['tobyfox', '8-4']     4.2         3.5K
# 4                                       ['Team Cherry']     4.4           3K
# ...                                                 ...     ...          ...
# 1507                                 ['Telltale Games']     3.2           94
# 1508                           ['Sumo Digital', 'Sega']     2.9          264
# 1509                                         ['Capcom']     3.7          210
# 1510                                 ['Larian Studios']     4.1          165
# 1511                          ['WB Games', 'TT Fusion']     2.8          184
#
#      review_cnt                                             genres plays  \
# 0          3.9K                               ['Adventure', 'RPG']   17K
# 1          2.9K           ['Adventure', 'Brawler', 'Indie', 'RPG']   21K
# 2          4.3K                               ['Adventure', 'RPG']   30K
# 3          3.5K  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...   28K
# 4            3K                 ['Adventure', 'Indie', 'Platform']   21K
# ...         ...                                                ...   ...
# 1507         94                   ['Adventure', 'Point-and-Click']   763
# 1508        264                               ['Arcade', 'Racing']  1.5K
# 1509        210                                 ['Brawler', 'RPG']  1.1K
# 1510        165  ['Adventure', 'RPG', 'Strategy', 'Tactical', '...   269
# 1511        184                            ['Adventure', 'Puzzle']  1.7K
#
#      Playing backlogs wishlist
# 0       3.8K     4.6K     4.8K
# 1       3.2K     6.3K     3.6K
# 2       2.5K       5K     2.6K
# 3        679     4.9K     1.8K
# 4       2.4K     8.3K     2.3K
# ...      ...      ...      ...
# 1507       5      223       67
# 1508      49      413      107
# 1509      45      487      206
# 1510      79      388      602
# 1511      11      239       73
#
# [1512 rows x 11 columns]

# %%
reviews_df['title'].value_counts().reset_index(name = 'cnt').sort_values(by = 'cnt', ascending = False).head(5)
# Out:
#                     title  cnt
# 0                    Doom    7
# 1         Resident Evil 2    5
# 2  Shadow of the Colossus    5
# 3              Dead Space    5
# 4               Minecraft    4

# %%
reviews_df[reviews_df['title'] == 'Doom']
# Out:
#      title  release_date                                   team  rating  \
# 45    Doom  May 12, 2016  ['id Software', 'Bethesda Softworks']     4.0
# 132   Doom  Dec 10, 1993          ['Activision', 'id Software']     4.0
# 371   Doom  May 12, 2016  ['id Software', 'Bethesda Softworks']     4.0
# 421   Doom  Dec 10, 1993          ['Activision', 'id Software']     4.0
# 821   Doom  May 12, 2016  ['id Software', 'Bethesda Softworks']     4.0
# 887   Doom  Dec 10, 1993          ['Activision', 'id Software']     4.0
# 1332  Doom  Nov 10, 2017  ['Bethesda Softworks', 'id Software']     3.9
#
#      times_listed review_cnt       genres plays Playing backlogs wishlist
# 45           1.8K       1.8K  ['Shooter']   18K     541       4K     1.4K
# 132          1.4K       1.4K  ['Shooter']   11K     203     1.5K      514
# 371          1.8K       1.8K  ['Shooter']   18K     541       4K     1.4K
# 421          1.4K       1.4K  ['Shooter']   11K     203     1.5K      514
# 821          1.8K       1.8K  ['Shooter']   18K     541       4K     1.4K
# 887          1.4K       1.4K  ['Shooter']   11K     203     1.5K      514
# 1332           80         80  ['Shooter']  2.3K      37      393      150

# %%
reviews_df[reviews_df['title'] == 'Resident Evil 2']
# Out:
#                 title  release_date  \
# 44    Resident Evil 2  Jan 25, 2019
# 370   Resident Evil 2  Jan 25, 2019
# 513   Resident Evil 2  Jan 21, 1998
# 820   Resident Evil 2  Jan 25, 2019
# 1026  Resident Evil 2  Jan 21, 1998
#
#                                              team  rating times_listed  \
# 44    ['Capcom', 'Capcom Development Division 1']     4.3         2.5K
# 370   ['Capcom', 'Capcom Development Division 1']     4.3         2.5K
# 513                        ['Capcom', 'Factor 5']     4.2         1.1K
# 820   ['Capcom', 'Capcom Development Division 1']     4.3         2.5K
# 1026                       ['Capcom', 'Factor 5']     4.2         1.1K
#
#      review_cnt                    genres plays Playing backlogs wishlist
# 44         2.5K  ['Adventure', 'Shooter']   15K     585     3.6K     1.9K
# 370        2.5K  ['Adventure', 'Shooter']   15K     585     3.6K     1.9K
# 513        1.1K  ['Adventure', 'Shooter']  5.5K      54     1.1K      597
# 820        2.5K  ['Adventure', 'Shooter']   15K     585     3.6K     1.9K
# 1026       1.1K  ['Adventure', 'Shooter']  5.5K      54     1.1K      597

# %%
duplicate_df = reviews_df[reviews_df.duplicated(['title', 'release_date'], keep = False)]
duplicate_df
# Out:
#                                         title  release_date  \
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1269                     Final Fantasy XIII-2  Dec 15, 2011
# 1270                                  Agar.io  Apr 28, 2015
# 1271        Fatal Frame II: Crimson Butterfly  Nov 27, 2003
# 1466                                  FIFA 13  Sep 25, 2012
# 1496                                  FIFA 13  Sep 25, 2012
#
#                                                    team  rating times_listed  \
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# 2     ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                    ['tobyfox', '8-4']     4.2         3.5K
# 4                                       ['Team Cherry']     4.4           3K
# ...                                                 ...     ...          ...
# 1269                                    ['Square Enix']     3.3          482
# 1270              ['Miniclip.com', 'Matheus Valadares']     2.2           81
# 1271       ['Tecmo Co., Ltd.', 'Ubisoft Entertainment']     4.2          398
# 1466                   ['Electronic Arts', 'EA Canada']     3.2           62
# 1496                   ['Electronic Arts', 'EA Canada']     3.2           62
#
#      review_cnt                                             genres plays  \
# 0          3.9K                               ['Adventure', 'RPG']   17K
# 1          2.9K           ['Adventure', 'Brawler', 'Indie', 'RPG']   21K
# 2          4.3K                               ['Adventure', 'RPG']   30K
# 3          3.5K  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...   28K
# 4            3K                 ['Adventure', 'Indie', 'Platform']   21K
# ...         ...                                                ...   ...
# 1269        482                               ['Adventure', 'RPG']  2.3K
# 1270         81                              ['Indie', 'Strategy']  4.4K
# 1271        398                                      ['Adventure']    1K
# 1466         62                             ['Simulator', 'Sport']  1.6K
# 1496         62                             ['Simulator', 'Sport']  1.6K
#
#      Playing backlogs wishlist
# 0       3.8K     4.6K     4.8K
# 1       3.2K     6.3K     3.6K
# 2       2.5K       5K     2.6K
# 3        679     4.9K     1.8K
# 4       2.4K     8.3K     2.3K
# ...      ...      ...      ...
# 1269      58     1.4K      449
# 1270       8       40       12
# 1271      38      690      513
# 1466       2       34       12
# 1496       2       34       12
#
# [674 rows x 11 columns]

# %%
reviews_df.drop_duplicates(['title', 'release_date'], inplace = True)
reviews_df
# Out:
#                                         title  release_date  \
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    team  rating times_listed  \
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5         3.9K
# 1                                  ['Supergiant Games']     4.3         2.9K
# 2     ['Nintendo', 'Nintendo EPD Production Group No...     4.4         4.3K
# 3                                    ['tobyfox', '8-4']     4.2         3.5K
# 4                                       ['Team Cherry']     4.4           3K
# ...                                                 ...     ...          ...
# 1507                                 ['Telltale Games']     3.2           94
# 1508                           ['Sumo Digital', 'Sega']     2.9          264
# 1509                                         ['Capcom']     3.7          210
# 1510                                 ['Larian Studios']     4.1          165
# 1511                          ['WB Games', 'TT Fusion']     2.8          184
#
#      review_cnt                                             genres plays  \
# 0          3.9K                               ['Adventure', 'RPG']   17K
# 1          2.9K           ['Adventure', 'Brawler', 'Indie', 'RPG']   21K
# 2          4.3K                               ['Adventure', 'RPG']   30K
# 3          3.5K  ['Adventure', 'Indie', 'RPG', 'Turn Based Stra...   28K
# 4            3K                 ['Adventure', 'Indie', 'Platform']   21K
# ...         ...                                                ...   ...
# 1507         94                   ['Adventure', 'Point-and-Click']   763
# 1508        264                               ['Arcade', 'Racing']  1.5K
# 1509        210                                 ['Brawler', 'RPG']  1.1K
# 1510        165  ['Adventure', 'RPG', 'Strategy', 'Tactical', '...   269
# 1511        184                            ['Adventure', 'Puzzle']  1.7K
#
#      Playing backlogs wishlist
# 0       3.8K     4.6K     4.8K
# 1       3.2K     6.3K     3.6K
# 2       2.5K       5K     2.6K
# 3        679     4.9K     1.8K
# 4       2.4K     8.3K     2.3K
# ...      ...      ...      ...
# 1507       5      223       67
# 1508      49      413      107
# 1509      45      487      206
# 1510      79      388      602
# 1511      11      239       73
#
# [1117 rows x 11 columns]

# %%
sales_df.isna().sum()
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher        58
# na_Sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
sales_df.fillna({'publisher': 'Unknown'}, inplace = True)
sales_df.isna().sum()
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher         0
# na_Sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
# if sales year is null then we put release year at sales year for that game
# games which are not present in reviews but are in sales are fine but games which are in reviews but not in sales are not fine

# %%
sales_df[(sales_df['year'].isna()) | (sales_df['name'][-4:].str.isnumeric())]
# Out:
#         rank                         name platform  year         genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     publisher  na_Sales  eu_sales  jp_sales  \
# 179                           Electronic Arts      4.26      0.26      0.01
# 377                           Electronic Arts      0.59      2.36      0.04
# 431    Warner Bros. Interactive Entertainment      1.86      1.02      0.00
# 470                                   Unknown      1.57      1.02      0.00
# 607                                     Atari      2.36      0.14      0.00
# ...                                       ...       ...       ...       ...
# 16307                                 Unknown      0.01      0.00      0.00
# 16327                      Namco Bandai Games      0.01      0.00      0.00
# 16366                                 Unknown      0.01      0.00      0.00
# 16427                                 Unknown      0.01      0.00      0.00
# 16493                                 Unknown      0.00      0.01      0.00
#
#        other_sales  global_sales
# 179           0.71          5.23
# 377           0.51          3.49
# 431           0.29          3.17
# 470           0.41          3.00
# 607           0.03          2.53
# ...            ...           ...
# 16307         0.00          0.01
# 16327         0.00          0.01
# 16366         0.00          0.01
# 16427         0.00          0.01
# 16493         0.00          0.01
#
# [271 rows x 11 columns]

# %%
reviews_df.isna().sum()
# Out:
# title            0
# release_date     0
# team             1
# rating          13
# times_listed     0
# review_cnt       0
# genres           0
# plays            0
# Playing          0
# backlogs         0
# wishlist         0
# dtype: int64

# %%
reviews_df[reviews_df['genres'].isna()]
# Out:
# Empty DataFrame
# Columns: [title, release_date, team, rating, times_listed, review_cnt, genres, plays, Playing, backlogs, wishlist]
# Index: []

# %%
import ast
reviews_df['genres'] = reviews_df['genres'].apply(ast.literal_eval)

def normalize_team(x):
    if pd.isna(x):
        return ['Unknown']
    if isinstance(x, list):
        return x
    if isinstance(x, str):
        return ast.literal_eval(x)
    return ['Unknown']

reviews_df['team'] = reviews_df['team'].apply(normalize_team)
reviews_df['genres'] = reviews_df['genres'].apply( lambda x: 'unknown' if len(x) == 0 else x)

# %%
games = reviews_df.drop(columns=['team', 'genres']).drop_duplicates()

game_teams = reviews_df[['title', 'team']].explode('team').drop_duplicates()

game_genres = reviews_df[['title', 'genres']].explode('genres').drop_duplicates()

# %%
df = sales_df.groupby(['name', 'year']).agg(
                               publisher_cnt = ('publisher', 'count'),
                               genre_cnt = ('genre', 'count')
)
df[df['genre_cnt'] > 1]
# Out:
#                                          publisher_cnt  genre_cnt
# name                             year
# 007: Quantum of Solace           2008.0              6          6
# 007: The World is not Enough     2000.0              2          2
# 187: Ride or Die                 2005.0              2          2
# 2002 FIFA World Cup              2002.0              3          3
# 2010 FIFA World Cup South Africa 2010.0              4          4
# ...                                                ...        ...
# iCarly                           2009.0              2          2
# iCarly 2: iJoin The Click!       2010.0              2          2
# nail'd                           2010.0              2          2
# pro evolution soccer 2011        2010.0              6          6
# uDraw Studio: Instant Artist     2011.0              2          2
#
# [2295 rows x 2 columns]

# %%
game_publisher_df = sales_df[['name', 'publisher']].dropna().drop_duplicates(subset = ['name', 'publisher'])
game_platform_df = sales_df[['name', 'platform']].dropna().drop_duplicates(subset = ['name', 'platform'])
sales_df.drop_duplicates(subset=['name', 'year'], inplace = True)
sales_df
# Out:
#         rank                                name platform    year  \
# 0          1                          Wii Sports      Wii  2006.0
# 1          2                   Super Mario Bros.      NES  1985.0
# 2          3                      Mario Kart Wii      Wii  2008.0
# 3          4                   Wii Sports Resort      Wii  2009.0
# 4          5            Pokemon Red/Pokemon Blue       GB  1996.0
# ...      ...                                 ...      ...     ...
# 16591  16594                 Myst IV: Revelation       PC  2004.0
# 16592  16595                            Plushees       DS  2008.0
# 16593  16596  Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594  16597       Men in Black II: Alien Escape       GC  2003.0
# 16596  16599                          Know How 2       DS  2010.0
#
#               genre   publisher  na_Sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16591     Adventure     Ubisoft      0.01      0.00      0.00         0.00
# 16592    Simulation   Destineer      0.01      0.00      0.00         0.00
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
#
#        global_sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16591          0.01
# 16592          0.01
# 16593          0.01
# 16594          0.01
# 16596          0.01
#
# [12363 rows x 11 columns]

# %%
gsales_genre = (
    sales_df[['name', 'genre']]
    .dropna()
    .drop_duplicates()
    .rename(columns={'name': 'title'})
)

game_genres = (
    game_genres
    .rename(columns={'genres': 'genre'})
)

games_genres = pd.concat([gsales_genre, game_genres], ignore_index=True).dropna().drop_duplicates(subset = ['title', 'genre'])
game_genres
# Out:
#                          title                genre
# 0                   Elden Ring            Adventure
# 0                   Elden Ring                  RPG
# 1                        Hades            Adventure
# 1                        Hades              Brawler
# 1                        Hades                Indie
# ...                        ...                  ...
# 1510           Baldur's Gate 3             Strategy
# 1510           Baldur's Gate 3             Tactical
# 1510           Baldur's Gate 3  Turn Based Strategy
# 1511  The LEGO Movie Videogame            Adventure
# 1511  The LEGO Movie Videogame               Puzzle
#
# [2648 rows x 2 columns]

# %%
sales_df.drop(columns = ['genre', 'publisher', 'platform'], inplace = True)
sales_df
# Out:
#         rank                                name    year  na_Sales  eu_sales  \
# 0          1                          Wii Sports  2006.0     41.49     29.02
# 1          2                   Super Mario Bros.  1985.0     29.08      3.58
# 2          3                      Mario Kart Wii  2008.0     15.85     12.88
# 3          4                   Wii Sports Resort  2009.0     15.75     11.01
# 4          5            Pokemon Red/Pokemon Blue  1996.0     11.27      8.89
# ...      ...                                 ...     ...       ...       ...
# 16591  16594                 Myst IV: Revelation  2004.0      0.01      0.00
# 16592  16595                            Plushees  2008.0      0.01      0.00
# 16593  16596  Woody Woodpecker in Crazy Castle 5  2002.0      0.01      0.00
# 16594  16597       Men in Black II: Alien Escape  2003.0      0.01      0.00
# 16596  16599                          Know How 2  2010.0      0.00      0.01
#
#        jp_sales  other_sales  global_sales
# 0          3.77         8.46         82.74
# 1          6.81         0.77         40.24
# 2          3.79         3.31         35.82
# 3          3.28         2.96         33.00
# 4         10.22         1.00         31.37
# ...         ...          ...           ...
# 16591      0.00         0.00          0.01
# 16592      0.00         0.00          0.01
# 16593      0.00         0.00          0.01
# 16594      0.00         0.00          0.01
# 16596      0.00         0.00          0.01
#
# [12363 rows x 8 columns]

# %%
games['times_listed'] = games['times_listed'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['review_cnt'] = games['review_cnt'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['plays'] = games['plays'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['Playing'] = games['Playing'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)
games['backlogs'] = games['backlogs'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)

games['wishlist'] = games['wishlist'].apply(
    lambda x: int(float(x[:-1]) * 1000) if isinstance(x, str) and x.lower().endswith('k')
    else int(x)
)


games
# Out:
#                                         title  release_date  rating  \
# 0                                  Elden Ring  Feb 25, 2022     4.5
# 1                                       Hades  Dec 10, 2019     4.3
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017     4.4
# 3                                   Undertale  Sep 15, 2015     4.2
# 4                               Hollow Knight  Feb 24, 2017     4.4
# ...                                       ...           ...     ...
# 1507             Back to the Future: The Game  Dec 22, 2010     3.2
# 1508                        Team Sonic Racing  May 21, 2019     2.9
# 1509                           Dragon's Dogma  May 22, 2012     3.7
# 1510                          Baldur's Gate 3  Oct 06, 2020     4.1
# 1511                 The LEGO Movie Videogame  Feb 04, 2014     2.8
#
#       times_listed  review_cnt  plays  Playing  backlogs  wishlist
# 0             3900        3900  17000     3800      4600      4800
# 1             2900        2900  21000     3200      6300      3600
# 2             4300        4300  30000     2500      5000      2600
# 3             3500        3500  28000      679      4900      1800
# 4             3000        3000  21000     2400      8300      2300
# ...            ...         ...    ...      ...       ...       ...
# 1507            94          94    763        5       223        67
# 1508           264         264   1500       49       413       107
# 1509           210         210   1100       45       487       206
# 1510           165         165    269       79       388       602
# 1511           184         184   1700       11       239        73
#
# [1117 rows x 9 columns]

# %%
sales_dtype = {'rank': 'int32', 'name': 'string', 'platform': 'category', 'year': 'int32', 'genre': 'category', 'publisher': 'string'}
games_dtype = {'title': 'string', 'release_date': 'datetime[ns]', 'rating': 'float', 'times_listed': 'int32', 'review_cnt': 'int32',
               'plays': 'int32', 'Playing': 'int32', 'backlogs': 'int32', 'wishlist': 'int32'}
games = games.convert_dtypes(games_dtype)
sales_df = sales_df.convert_dtypes(sales_dtype)
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 12363 entries, 0 to 16596
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          12363 non-null  Int64
#  1   name          12363 non-null  string
#  2   year          12130 non-null  Int64
#  3   na_Sales      12363 non-null  Float64
#  4   eu_sales      12363 non-null  Float64
#  5   jp_sales      12363 non-null  Float64
#  6   other_sales   12363 non-null  Float64
#  7   global_sales  12363 non-null  Float64
# dtypes: Float64(5), Int64(2), string(1)
# memory usage: 953.8 KB

# %%
games.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1117 entries, 0 to 1511
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1117 non-null   string
#  1   release_date  1117 non-null   string
#  2   rating        1104 non-null   Float64
#  3   times_listed  1117 non-null   Int64
#  4   review_cnt    1117 non-null   Int64
#  5   plays         1117 non-null   Int64
#  6   Playing       1117 non-null   Int64
#  7   backlogs      1117 non-null   Int64
#  8   wishlist      1117 non-null   Int64
# dtypes: Float64(1), Int64(6), string(2)
# memory usage: 94.9 KB

# %%
numeric_cols = games.select_dtypes(exclude=['string']).columns
for col in numeric_cols:
    print(col, games[col].min(), games[col].max())
# Out:
# rating 0.7 4.8
# times_listed 0 4300
# review_cnt 0 4300
# plays 0 33000
# Playing 0 3800
# backlogs 1 8300
# wishlist 2 5400

# %%
numeric_cols = sales_df.select_dtypes(exclude=['string']).columns
for col in numeric_cols:
    print(col, sales_df[col].min(), sales_df[col].max())
# Out:
# rank 1 16599
# year 1980 2020
# na_Sales 0.0 41.49
# eu_sales 0.0 29.02
# jp_sales 0.0 10.22
# other_sales 0.0 10.57
# global_sales 0.01 82.74

# %%
games.to_csv('./dataset/games_ratings.csv', index = False)
game_teams.to_csv('./dataset/game_teams.csv', index = False)
game_genres.to_csv('./dataset/game_genres.csv', index = False)
sales_df.to_csv('./dataset/game_sales.csv', index = False)
game_publisher_df.to_csv('./dataset/game_publisher.csv', index = False)
game_platform_df.to_csv('./dataset/game_platform.csv', index = False)

# %% [markdown]
# ## SQL Server connect

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
database_name = 'videogames'
server_name = 'DESKTOP-I3SV1NI'
driver = 'ODBC Driver 17 for SQL Server'

connect_str = f'mssql+pyodbc://{server_name}/{database_name}?trusted_connection=yes&driver={driver}'
engine = create_engine(connect_str)
